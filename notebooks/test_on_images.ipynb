# %%
import sys, os
sys.path.append(os.pardir)

# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from src.detect import FaceDetector
from src import set_figsize, show_bboxes

# %%
detector = FaceDetector(min_face_size=10.0)

set_figsize((7, 5))

image = Image.open('../asset/office5.jpg')
bounding_boxes = detector.detect(image)

fig = plt.imshow(image) 
show_bboxes(fig.axes, bounding_boxes)
# Out:
# torch.Size([908, 4])
# torch.Size([57, 4])
# torch.Size([57, 4])
# torch.Size([21, 4])
# torch.Size([13, 4])
